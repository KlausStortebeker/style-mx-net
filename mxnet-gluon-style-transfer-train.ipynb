# %%
cd
# Out:
# /root

# %%
# !git clone https://github.com/Stortebeker/style-mx-net.git style

# %%
cd style
# Out:
# /root/style

# %%
# !python dataset/download_dataset.py
# Out:
# /root/style

# %%
# !rm -rf dataset/train2014.zip
# !rm -rf dataset/val2014.zip

# %%
# !mkdir images
# !mkdir styles
# Out:
# README.md  dataset/            images/  models/  option.py  utils.py
# data.py    download_images.py  main.py  net.py   styles/

# %%
# !wget https://i.imgur.com/gbV7bQF.jpeg -P styles
# Out:
# --2021-09-18 13:34:14--  https://i.imgur.com/gbV7bQF.jpeg
# Resolving i.imgur.com (i.imgur.com)... 199.232.32.193
# Connecting to i.imgur.com (i.imgur.com)|199.232.32.193|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 134319 (131K) [image/jpeg]
# Saving to: ‘styles/gbV7bQF.jpeg’
#
# gbV7bQF.jpeg        100%[===================>] 131.17K  --.-KB/s    in 0.1s
#
# 2021-09-18 13:34:14 (1.13 MB/s) - ‘styles/gbV7bQF.jpeg’ saved [134319/134319]

# %%
# !mkdir results

# %%
# !python main.py train --epochs 4 --style-folder styles/ --batch-size 16 --cuda 1 --save-model-dir results
# Out:
# len(style_loader): 1
# --2021-09-18 13:41:16--  https://www.dropbox.com/s/7c92s0guekwrwzf/mxvgg.params?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.9.18, 2620:100:601f:18::a27d:912
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.9.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/7c92s0guekwrwzf/mxvgg.params [following]
# --2021-09-18 13:41:16--  https://www.dropbox.com/s/dl/7c92s0guekwrwzf/mxvgg.params
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc056650eb1ee0ddc841f16fd2c1.dl.dropboxusercontent.com/cd/0/get/BWadCN-ag8S1B9R0sTxl3vF8a_KAMwLoew1AH8QoT8jA2gwQm_1tPOetLYBRfMG2TR9Yj9BZ6HQJDDfSPGVAiJlct3Ni7aOSvs363EIgSRCcNxyV1qypsMxkgOl5LRmaXDSyx-B-VhsvBOLlTHWiQM-t/file?dl=1# [following]
# ...
